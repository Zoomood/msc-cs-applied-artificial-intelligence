# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import re
import glob

# %%
#Create a dataframe with all the "mortality rates file"
mortality = pd.concat([pd.read_csv(one_filename, header =[0,1])#use header =[] to read multi-level headers from the file
     for one_filename in glob.glob('Child mortality rates*')])
mortality.shape
# Out:
# (12468, 8)

# %%
# Combine the multi-level headers into one by concatenating them with an underscore
mortality.columns = [
    col_1 if "Unnamed" in col_0 else f"{col_0}_{col_1}"
    for col_0, col_1 in mortality.columns
]

# %%
mortality.columns
# Out:
# Index(['Countries, territories and areas', 'Year',
#        'Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes',
#        'Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male',
#        'Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female',
#        'Number of deaths among children under-five_ Both sexes',
#        'Number of deaths among children under-five_ Male',
#        'Number of deaths among children under-five_ Female'],
#       dtype='object')

# %%
mortality.head(10)
# Out:
#   Countries, territories and areas  Year  \
# 0                        Australia  2021
# 1                        Australia  2020
# 2                        Australia  2019
# 3                        Australia  2018
# 4                        Australia  2017
# 5                        Australia  2016
# 6                        Australia  2015
# 7                        Australia  2014
# 8                        Australia  2013
# 9                        Australia  2012
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes  \
# 0                                    3.71 [3.5-3.94]
# 1                                    3.74 [3.6-3.89]
# 2                                   3.75 [3.66-3.86]
# 3                                   3.76 [3.68-3.85]
# 4                                   3.78 [3.69-3.86]
# 5                                    3.81 [3.72-3.9]
# 6                                   3.87 [3.79-3.96]
# 7                                   3.98 [3.89-4.07]
# 8                                   4.13 [4.04-4.21]
# 9                                   4.32 [4.23-4.41]
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male  \
# 0                                    4.04 [3.8-4.29]
# 1                                    4.07 [3.9-4.24]
# 2                                   4.09 [3.96-4.22]
# 3                                    4.1 [3.98-4.21]
# 4                                    4.1 [3.99-4.22]
# 5                                   4.13 [4.02-4.25]
# 6                                    4.2 [4.08-4.31]
# 7                                   4.31 [4.19-4.42]
# 8                                   4.48 [4.36-4.59]
# 9                                    4.7 [4.59-4.82]
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female  \
# 0                                   3.37 [3.16-3.59]
# 1                                    3.4 [3.25-3.55]
# 2                                    3.4 [3.29-3.52]
# 3                                   3.41 [3.31-3.52]
# 4                                   3.43 [3.33-3.53]
# 5                                   3.47 [3.37-3.57]
# 6                                   3.53 [3.43-3.64]
# 7                                   3.63 [3.52-3.73]
# 8                                   3.76 [3.65-3.86]
# 9                                   3.91 [3.81-4.02]
#
#   Number of deaths among children under-five_ Both sexes  \
# 0                                1 111 [1 048-1 178]
# 1                                1 130 [1 089-1 174]
# 2                                1 171 [1 140-1 203]
# 3                                1 183 [1 156-1 210]
# 4                                1 169 [1 143-1 195]
# 5                                1 168 [1 141-1 195]
# 6                                1 171 [1 145-1 197]
# 7                                1 202 [1 174-1 229]
# 8                                1 258 [1 231-1 285]
# 9                                1 304 [1 277-1 332]
#
#   Number of deaths among children under-five_ Male  \
# 0                                    620 [584-660]
# 1                                    631 [606-659]
# 2                                    655 [635-677]
# 3                                    662 [644-681]
# 4                                    653 [636-672]
# 5                                    652 [634-670]
# 6                                    652 [634-670]
# 7                                    669 [651-687]
# 8                                    701 [683-719]
# 9                                    729 [712-748]
#
#   Number of deaths among children under-five_ Female
# 0                                      491 [460-523]
# 1                                      499 [477-521]
# 2                                      516 [498-534]
# 3                                      521 [505-537]
# 4                                      516 [501-531]
# 5                                      516 [502-532]
# 6                                      519 [504-534]
# 7                                      533 [518-548]
# 8                                      557 [541-572]
# 9                                      575 [560-591]

# %%
def clean_numeric_dataframe(df):
    def clean_value(x):
        if isinstance(x, str):
            return re.sub(r"\[.*\]", "", str(x)).strip()
        return x
    return df.map(clean_value)

# clean numerical columns
mortality = clean_numeric_dataframe(mortality)
mortality.head(10)
# Out:
#   Countries, territories and areas  Year  \
# 0                        Australia  2021
# 1                        Australia  2020
# 2                        Australia  2019
# 3                        Australia  2018
# 4                        Australia  2017
# 5                        Australia  2016
# 6                        Australia  2015
# 7                        Australia  2014
# 8                        Australia  2013
# 9                        Australia  2012
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes  \
# 0                                               3.71
# 1                                               3.74
# 2                                               3.75
# 3                                               3.76
# 4                                               3.78
# 5                                               3.81
# 6                                               3.87
# 7                                               3.98
# 8                                               4.13
# 9                                               4.32
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male  \
# 0                                               4.04
# 1                                               4.07
# 2                                               4.09
# 3                                                4.1
# 4                                                4.1
# 5                                               4.13
# 6                                                4.2
# 7                                               4.31
# 8                                               4.48
# 9                                                4.7
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female  \
# 0                                               3.37
# 1                                                3.4
# 2                                                3.4
# 3                                               3.41
# 4                                               3.43
# 5                                               3.47
# 6                                               3.53
# 7                                               3.63
# 8                                               3.76
# 9                                               3.91
#
#   Number of deaths among children under-five_ Both sexes  \
# 0                                              1 111
# 1                                              1 130
# 2                                              1 171
# 3                                              1 183
# 4                                              1 169
# 5                                              1 168
# 6                                              1 171
# 7                                              1 202
# 8                                              1 258
# 9                                              1 304
#
#   Number of deaths among children under-five_ Male  \
# 0                                              620
# 1                                              631
# 2                                              655
# 3                                              662
# 4                                              653
# 5                                              652
# 6                                              652
# 7                                              669
# 8                                              701
# 9                                              729
#
#   Number of deaths among children under-five_ Female
# 0                                                491
# 1                                                499
# 2                                                516
# 3                                                521
# 4                                                516
# 5                                                516
# 6                                                519
# 7                                                533
# 8                                                557
# 9                                                575

# %%
nutrition = pd.read_csv('Infant nutrition data by country.csv')

# %%
nutrition.head(5)
# Out:
#   Countries, territories and areas        Year  \
# 0                      Afghanistan        2018
# 1                      Afghanistan   2015-2016
# 2                      Afghanistan        2015
# 3                          Albania        2017
# 4                          Albania        2009
#
#    Early initiation of breastfeeding (%)  \
# 0                                    NaN
# 1                                   40.9
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                               57.5
# 1                                                NaN
# 2                                   43.1 [40.1-46.2]
# 3                                   36.5 [29.8-43.9]
# 4                                   37.1 [27.1-48.5]

# %%
nutrition = clean_numeric_dataframe (nutrition)
nutrition.head(5)
# Out:
#   Countries, territories and areas       Year  \
# 0                      Afghanistan       2018
# 1                      Afghanistan  2015-2016
# 2                      Afghanistan       2015
# 3                          Albania       2017
# 4                          Albania       2009
#
#    Early initiation of breastfeeding (%)  \
# 0                                    NaN
# 1                                   40.9
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                               57.5
# 1                                                NaN
# 2                                               43.1
# 3                                               36.5
# 4                                               37.1

# %%
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.options.mode.chained_assignment = None


def split_year_range(df: pd.DataFrame):
    """
    Finds rows with 'Year' column values representing a range of values,
    delimited by a '-' character. Produces copies of the row for all years 
    in the range. Drops the original row from the dataframe. Returns DataFrame
    containing new rows and list of original indices where splits occurred.
    """
    rows_to_add = []
    indices_to_drop = []
    for i, row in df.iterrows():
        year = row['Year']
        if '-' in year:
            start_year, end_year = year.split('-')
            for y in range(int(start_year), int(end_year) + 1):
                new_row = row.copy()
                new_row['Year'] = str(y)
                rows_to_add.append(new_row)
            indices_to_drop.append(i)
    return pd.DataFrame(rows_to_add).reset_index(drop=True), indices_to_drop

# get new rows from splitting range values
split_df, indices_to_drop = split_year_range(nutrition)
# drop original rows
for x in indices_to_drop:
    nutrition.drop(x, inplace=True)
nutrition.reset_index(inplace=True, drop=True)

# append new rows from split
nutrition = pd.concat([nutrition, split_df]).reset_index(drop=True)

# cast Year to integer
nutrition['Year'] = nutrition["Year"].astype('int')

# sort rows
nutrition = nutrition.sort_values(by=['Countries, territories and areas','Year'], ascending=False)
nutrition.reset_index(inplace=True, drop=True)

# group rows by country and year
grouped = nutrition.groupby(['Countries, territories and areas', 'Year'])
group_list = []
for i, group in grouped:
    # skip groups with only one value
    if group.shape[0] == 1:
        group_list.append(group)
        continue
    # for each group, backfill/frontfill
    group.bfill(inplace=True)
    group.ffill(inplace=True)
    group_list.append(group)
    
# concatenate all groups, reset index, drop copies
nutrition = pd.concat(group_list).reset_index(drop=True).drop_duplicates()

# %%
nutrition.head(5)
# Out:
#   Countries, territories and areas  Year  \
# 0                      Afghanistan  2015
# 2                      Afghanistan  2016
# 3                      Afghanistan  2018
# 4                          Albania  2000
# 5                          Albania  2005
#
#    Early initiation of breastfeeding (%)  \
# 0                                   40.9
# 2                                   40.9
# 3                                    NaN
# 4                                    NaN
# 5                                   29.9
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                                               43.1
# 2                                                                NaN
# 3                                                               57.5
# 4                                                                6.3
# 5                                                                3.4

# %%
#test_data = mortality[mortality['Countries, territories and areas'] == 'Peru']

# Display the filtered rows
#print(test_data)

# %%
df=pd.merge(mortality, nutrition, on=['Countries, territories and areas', 'Year'],how='outer')

# %%
df.head(5)
# Out:
#   Countries, territories and areas  Year  \
# 0                      Afghanistan  1957
# 1                      Afghanistan  1958
# 2                      Afghanistan  1959
# 3                      Afghanistan  1960
# 4                      Afghanistan  1961
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes  \
# 0                                                                   375.91
# 1                                                                   369.63
# 2                                                                   363.44
# 3                                                                    357.3
# 4                                                                   351.66
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   Number of deaths among children under-five_ Both sexes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   Number of deaths among children under-five_ Male  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Number of deaths among children under-five_ Female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Early initiation of breastfeeding (%)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN

# %%
#test_data = df[df['Countries, territories and areas'] == 'Afghanistan']

# Display the filtered rows
#print(test_data)

# %%
#df.to_csv('Final_combined_dataset.csv', index = False)

# %%
df.dtypes
# Out:
# Countries, territories and areas                                             object
# Year                                                                          int64
# Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes     object
# Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male           object
# Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female         object
# Number of deaths among children under-five_ Both sexes                       object
# Number of deaths among children under-five_ Male                             object
# Number of deaths among children under-five_ Female                           object
# Early initiation of breastfeeding (%)                                       float64
# Infants exclusively breastfed for the first six months of life (%)           object
# dtype: object

# %%
df.head(10)
# Out:
#   Countries, territories and areas  Year  \
# 0                      Afghanistan  1957
# 1                      Afghanistan  1958
# 2                      Afghanistan  1959
# 3                      Afghanistan  1960
# 4                      Afghanistan  1961
# 5                      Afghanistan  1962
# 6                      Afghanistan  1963
# 7                      Afghanistan  1964
# 8                      Afghanistan  1965
# 9                      Afghanistan  1966
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes  \
# 0                                                                   375.91
# 1                                                                   369.63
# 2                                                                   363.44
# 3                                                                    357.3
# 4                                                                   351.66
# 5                                                                   345.84
# 6                                                                   340.16
# 7                                                                   334.85
# 8                                                                   329.42
# 9                                                                   323.94
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
# 5                                                                NaN
# 6                                                             347.67
# 7                                                             342.12
# 8                                                             336.52
# 9                                                             330.99
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
# 5                                                                  NaN
# 6                                                               331.86
# 7                                                               326.93
# 8                                                               321.56
# 9                                                                316.2
#
#   Number of deaths among children under-five_ Both sexes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
#
#   Number of deaths among children under-five_ Male  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
#
#   Number of deaths among children under-five_ Female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Early initiation of breastfeeding (%)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
# 5                                                                NaN
# 6                                                                NaN
# 7                                                                NaN
# 8                                                                NaN
# 9                                                                NaN

# %%
df.head(5)
# Out:
#   Countries, territories and areas  Year  \
# 0                      Afghanistan  1957
# 1                      Afghanistan  1958
# 2                      Afghanistan  1959
# 3                      Afghanistan  1960
# 4                      Afghanistan  1961
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Both sexes  \
# 0                                                                   375.91
# 1                                                                   369.63
# 2                                                                   363.44
# 3                                                                    357.3
# 4                                                                   351.66
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Male  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#   Under-five mortality rate (per 1000 live births) (SDG 3.2.1)_ Female  \
# 0                                                                  NaN
# 1                                                                  NaN
# 2                                                                  NaN
# 3                                                                  NaN
# 4                                                                  NaN
#
#   Number of deaths among children under-five_ Both sexes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
#   Number of deaths among children under-five_ Male  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Number of deaths among children under-five_ Female  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Early initiation of breastfeeding (%)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Infants exclusively breastfed for the first six months of life (%)
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
